# %%
class CallableClass:
    def __init__(self):
        self.counter = 0
        
    def __call__(self):
        self.counter += 1
        print(self.counter)

# %%
c = CallableClass()

# %%
c()
# Out:
# 1

# %%
c.__call__()
# Out:
# 2

# %%
def fibbonacci(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibbonacci(n-1) + fibbonacci(n-2)

# %%
fibbonacci(60)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-855d83946c24> in <module>()
# ----> 1 fibbonacci(60)
#
# <ipython-input-21-b89a503d3982> in fibbonacci(n)
#       5         return 1
#       6     else:
# ----> 7         return fibbonacci(n-1) + fibbonacci(n-2)
#
# <ipython-input-21-b89a503d3982> in fibbonacci(n)
#       5         return 1
#       6     else:
# ----> 7         return fibbonacci(n-1) + fibbonacci(n-2)
#
# <ipython-input-21-b89a503d3982> in fibbonacci(n)
#       5         return 1
#       6     else:
# ----> 7         return fibbonacci(n-1) + fibbonacci(n-2)
#
# <ipython-input-21-b89a503d3982> in fibbonacci(n)
#       5         return 1
#       6     else:
# ----> 7         return fibbonacci(n-1) + fibbonacci(n-2)
#
# <ipython-input-21-b89a503d3982> in fibbonacci(n)
#       5         return 1
#       6     else:
# ...

# %%
# %%HTML
# <style>
# div.text_cell div.prompt {
#     display: none;
# }
# </style>
# Out:
# <style>
# div.text_cell div.prompt {
#     display: none;
# }
# </style>
